# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from detect_vehicles import VehicleDetection
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

img = mpimg.imread('./examples/bbox-example-image.jpg')
detector = VehicleDetection()
with_cars = detector.detect(img)
plt.imshow(with_cars)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loaded model with 0.991397849462 accuracy
